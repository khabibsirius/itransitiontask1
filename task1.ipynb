# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def type_extraction(price):
    if '$' in price:
        return "DOLLAR"
    elif 'â‚¬' in price:
        return "EURO"
    else:
        return price.str.replace(',', '.')

# %%
df = pd.read_json("datas/task1_cleaned.json")
df.head()
# Out:
#                      id                              title  \
# 0  10292064894005717421               Look Homeward, Angel
# 1  13029911509625386835       The Yellow Meads of Asphodel
# 2  12880574241579659568                   A Catskill Eagle
# 3  13301315742612799364        Der Richter und sein Henker
# 4  16372759776603821045  After Many a Summer Dies the Swan
#
#                   author                genre                      publisher  \
# 0  Prof. Teressa Kautzer                Humor               Brill Publishers
# 1        Domingo Weimann       Reference book                Sams Publishing
# 2              Dayle Orn  Comic/Graphic Novel                         Apress
# 3         Elias von Kolb            Tall tale               Centaurus Verlag
# 4          Carter Legros          Metafiction  University of Minnesota Press
#
#    year    price
# 0  2010   $87.25
# 1  2018   $31.99
# 2  2011  â‚¬5.99
# 3  1995   $75.00
# 4  2004    $52.0

# %%
df['type'] = df.price.apply(type_extraction)

# %%
df.head()
# Out:
#                      id                              title  \
# 0  10292064894005717421               Look Homeward, Angel
# 1  13029911509625386835       The Yellow Meads of Asphodel
# 2  12880574241579659568                   A Catskill Eagle
# 3  13301315742612799364        Der Richter und sein Henker
# 4  16372759776603821045  After Many a Summer Dies the Swan
#
#                   author                genre                      publisher  \
# 0  Prof. Teressa Kautzer                Humor               Brill Publishers
# 1        Domingo Weimann       Reference book                Sams Publishing
# 2              Dayle Orn  Comic/Graphic Novel                         Apress
# 3         Elias von Kolb            Tall tale               Centaurus Verlag
# 4          Carter Legros          Metafiction  University of Minnesota Press
#
#    year    price    type
# 0  2010   $87.25  DOLLAR
# 1  2018   $31.99  DOLLAR
# 2  2011  â‚¬5.99    EURO
# 3  1995   $75.00  DOLLAR
# 4  2004    $52.0  DOLLAR

# %%
df.price = df.price.str.replace('â‚¬', '').str.replace('$', '').str.replace(',', '')

# %%
df.price = df.price.astype(float)

# %%
df.price.min()
# Out:
# np.float64(4.0)

# %%
df.loc[df['type'] == 'EURO', 'price'] = df.loc[df['type'] == 'EURO', 'price'] * 1.2

# %%
df.drop(columns=['type'], inplace=True)

# %%
df.head()
# Out:
#                      id                              title  \
# 0  10292064894005717421               Look Homeward, Angel
# 1  13029911509625386835       The Yellow Meads of Asphodel
# 2  12880574241579659568                   A Catskill Eagle
# 3  13301315742612799364        Der Richter und sein Henker
# 4  16372759776603821045  After Many a Summer Dies the Swan
#
#                   author                genre                      publisher  \
# 0  Prof. Teressa Kautzer                Humor               Brill Publishers
# 1        Domingo Weimann       Reference book                Sams Publishing
# 2              Dayle Orn  Comic/Graphic Novel                         Apress
# 3         Elias von Kolb            Tall tale               Centaurus Verlag
# 4          Carter Legros          Metafiction  University of Minnesota Press
#
#    year   price
# 0  2010  87.250
# 1  2018  31.990
# 2  2011   7.188
# 3  1995  75.000
# 4  2004  52.000

# %%
df.price
# Out:
# 0       87.250
# 1       31.990
# 2        7.188
# 3       75.000
# 4       52.000
#          ...
# 4998    72.500
# 4999    56.000
# 5000    80.388
# 5001    29.000
# 5002    97.500
# Name: price, Length: 5003, dtype: float64

# %%
df.columns
# Out:
# Index(['id', 'title', 'author', 'genre', 'publisher', 'year', 'price'], dtype='object')

# %%
summary_table = df.groupby('year').agg(
    book_count=('id', 'count'),
    average_price=('price', 'mean')
).reset_index()
summary_table['average_price'] = summary_table['average_price'].round(2)
summary_table = summary_table.rename(columns={'year': 'publication_year'})
summary_table = summary_table.sort_values('publication_year').reset_index(drop=type)
print(summary_table)
# Out:
#     publication_year  book_count  average_price
# 0               1871          43          48.08
# 1               1883          56          52.51
# 2               1886          54          54.73
# 3               1904          37          54.74
# 4               1905          59          50.62
# 5               1938          42          46.76
# 6               1955          49          54.83
# 7               1958          32          44.17
# 8               1986         104          45.63
# 9               1987         120          50.44
# 10              1988         153          49.91
# 11              1989         103          50.39
# 12              1990         122          52.12
# 13              1991          94          50.01
# 14              1992         101          50.46
# 15              1993         114          51.80
# 16              1994         131          50.55
# 17              1995         112          44.93
# 18              1996         111          54.12
# 19              1997         111          49.94
# 20              1998         110          51.53
# 21              1999         108          52.17
# 22              2000         107          45.64
# 23              2001         117          48.68
# 24              2002         101          49.88
# 25              2003         103          53.53
# 26              2004         174          51.73
# 27              2005         116          51.34
# 28              2006         128          54.89
# 29              2007         113          47.03
# 30              2008          92          50.24
# 31              2009          99          51.01
# 32              2010         101          52.18
# 33              2011         122          51.34
# 34              2012         120          53.64
# 35              2013         114          52.12
# 36              2014         100          53.31
# 37              2015         107          52.77
# 38              2016         127          48.66
# 39              2017         119          52.91
# 40              2018         113          52.28
# 41              2019         104          53.68
# 42              2020         107          51.88
# 43              2021         124          54.10
# 44              2022         103          48.43
# 45              2023          94          49.12
# 46              2024         108          53.81
# 47              2025         108          51.74
# 48              2026         116          50.13
